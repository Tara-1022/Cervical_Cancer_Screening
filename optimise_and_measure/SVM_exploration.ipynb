# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv(r"\Features_training.csv", 
                       index_col="Unnamed: 0")
train_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.032952 -0.089260  0.995986 -0.039308  0.068185  1.373475 -0.028986
# 1   -0.009248 -0.072009  0.992089 -0.030511 -0.081038  1.290843  0.347199
# 2   -0.005045 -0.137277  0.438054 -0.074769 -0.051198  1.571595 -0.084830
# 3   -0.010505 -0.038796  0.834873 -0.048714 -0.032284  0.528445  0.100358
# 4   -0.004975  0.007129  1.644052 -0.032443  0.000001  0.510549  0.772788
# ..        ...       ...       ...       ...       ...       ...       ...
# 755  0.861623  0.922035 -0.043221 -0.030535  0.563633 -0.091188 -0.030903
# 756  0.108196  0.174007 -0.043465  0.770435 -0.041426  0.018064  0.116704
# 757  0.426622  0.217156 -0.028136  0.019139  0.719309 -0.074509 -0.062391
# 758  0.840988 -0.078214  0.029280  1.118820  0.229640  0.153103  0.075561
# 759  0.037244  0.141647 -0.006495  1.861162  0.304336 -0.043681 -0.049558
#
#             7         8         9  ...      1272      1273      1274  \
# ...

# %%
val_df = pd.read_csv(r"\Features_validation.csv", 
                       index_col="Unnamed: 0")
val_df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.006334  0.107281  0.538081  0.028678 -0.028234  0.419449  0.219239
# 1   -0.002649 -0.085481  0.281293 -0.033233 -0.093744  0.054726  0.065228
# 2   -0.001529  0.023238  0.011623  0.028935  0.196433  0.389306 -0.121486
# 3   -0.019128  0.076994  0.373053 -0.042577  0.103818  0.101742  0.212550
# 4   -0.026128  0.792143  0.177022 -0.035228  0.127684 -0.031569  0.049721
# ..        ...       ...       ...       ...       ...       ...       ...
# 185  0.471256  0.187628  0.081938  0.356160  0.778837  0.457533 -0.027622
# 186  0.918917  0.138324  0.017251  0.709525  0.646340 -0.071009  0.104825
# 187 -0.033326  0.210831  0.051467  0.045335  0.090301  0.033713  0.610606
# 188 -0.027837 -0.065755 -0.016305  0.051547  0.108510  0.177839  0.260694
# 189 -0.008216  0.438198  0.111163  0.070731 -0.057439  0.332347 -0.042364
#
#             7         8         9  ...      1272      1273      1274  \
# ...

# %%
feature_indices = list(map(str, range(1280)))
print(min(feature_indices), max(feature_indices))
print(feature_indices)
label_index = '1280'
image_index = '1281'
# Out:
# 0 999
# ...

# %%
print(train_df[label_index])
print(train_df[feature_indices])
# Out:
# 0      CIN1-
# 1      CIN1-
# 2      CIN1-
# 3      CIN1-
# 4      CIN1-
#        ...
# 755    CIN2+
# 756    CIN2+
# 757    CIN2+
# 758    CIN2+
# 759    CIN2+
# Name: 1280, Length: 760, dtype: object
#             0         1         2         3         4         5         6  \
# 0    0.032952 -0.089260  0.995986 -0.039308  0.068185  1.373475 -0.028986
# 1   -0.009248 -0.072009  0.992089 -0.030511 -0.081038  1.290843  0.347199
# 2   -0.005045 -0.137277  0.438054 -0.074769 -0.051198  1.571595 -0.084830
# 3   -0.010505 -0.038796  0.834873 -0.048714 -0.032284  0.528445  0.100358
# 4   -0.004975  0.007129  1.644052 -0.032443  0.000001  0.510549  0.772788
# ..        ...       ...       ...       ...       ...       ...       ...
# 755  0.861623  0.922035 -0.043221 -0.030535  0.563633 -0.091188 -0.030903
# 756  0.108196  0.174007 -0.043465  0.770435 -0.041426  0.018064  0.116704
# 757  0.426622  0.217156 -0.028136  0.019139  0.719309 -0.074509 -0.062391
# ...

# %%
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from sklearn.preprocessing import MinMaxScaler

features = train_df[feature_indices]
min_max_scaler = MinMaxScaler()
scaled = min_max_scaler.fit_transform(features)
df = pd.DataFrame(scaled)
print(features)
print(scaled)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.032952 -0.089260  0.995986 -0.039308  0.068185  1.373475 -0.028986
# 1   -0.009248 -0.072009  0.992089 -0.030511 -0.081038  1.290843  0.347199
# 2   -0.005045 -0.137277  0.438054 -0.074769 -0.051198  1.571595 -0.084830
# 3   -0.010505 -0.038796  0.834873 -0.048714 -0.032284  0.528445  0.100358
# 4   -0.004975  0.007129  1.644052 -0.032443  0.000001  0.510549  0.772788
# ..        ...       ...       ...       ...       ...       ...       ...
# 755  0.861623  0.922035 -0.043221 -0.030535  0.563633 -0.091188 -0.030903
# 756  0.108196  0.174007 -0.043465  0.770435 -0.041426  0.018064  0.116704
# 757  0.426622  0.217156 -0.028136  0.019139  0.719309 -0.074509 -0.062391
# 758  0.840988 -0.078214  0.029280  1.118820  0.229640  0.153103  0.075561
# 759  0.037244  0.141647 -0.006495  1.861162  0.304336 -0.043681 -0.049558
#
#             7         8         9  ...      1270      1271      1272  \
# ...

# %%
from sklearn.metrics import classification_report

# %%
clf = svm.SVC()
clf.fit(scaled, train_df[label_index])
# Out:
# SVC()

# %%
print(clf.support_.shape)
clf.support_
# Out:
# (111,)
# array([ 31,  42,  43,  50,  54,  55,  59,  62,  76,  90, 104, 108, 113,
#        121, 128, 130, 132, 145, 156, 157, 160, 171, 176, 183, 184, 186,
#        191, 192, 198, 203, 207, 233, 244, 250, 266, 276, 283, 294, 302,
#        304, 305, 307, 308, 309, 310, 320, 321, 322, 323, 336, 338, 345,
#        356, 381, 389, 392, 402, 411, 414, 422, 426, 428, 429, 433, 442,
#        444, 458, 468, 481, 494, 499, 502, 504, 514, 517, 519, 521, 535,
#        552, 562, 572, 574, 583, 584, 586, 600, 602, 604, 618, 626, 638,
#        639, 646, 649, 659, 663, 666, 667, 681, 682, 705, 706, 707, 711,
#        712, 716, 720, 737, 738, 745, 756])

# %%
clf.n_support_
# Out:
# array([53, 58])

# %%
clf.support_vectors_.shape
# Out:
# (111, 1280)

# %%
predicted = clf.predict(min_max_scaler.transform(val_df[feature_indices]))
print(classification_report(val_df[label_index], predicted))
# Out:
#               precision    recall  f1-score   support
#
#        CIN1-       0.85      0.88      0.87        95
#        CIN2+       0.88      0.84      0.86        95
#
#     accuracy                           0.86       190
#    macro avg       0.86      0.86      0.86       190
# weighted avg       0.86      0.86      0.86       190

# %% [markdown]
# # Further exploration (no major improvement)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=50)
selected = pca.fit_transform(scaled)

# %%
selected.shape
# Out:
# (760, 50)

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(selected, train_df[label_index])
# Out:
# SVC()

# %%
test_1 = val_df[val_df[image_index] == "AAAX6.jpg"]
print(test_1)
print(test_1[label_index])
test_1_features = pca.transform(test_1[feature_indices])
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.006334  0.107281  0.538081  0.028678 -0.028234  0.419449  0.219239
#
#           7         8         9  ...      1272      1273     1274      1275  \
# 0 -0.068741 -0.022731  0.136897  ...  0.101971  0.014383  0.03002  0.340704
#
#        1276      1277      1278      1279   1280       1281
# 0  0.086828  0.320838  0.062928 -0.011567  CIN1-  AAAX6.jpg
#
# [1 rows x 1282 columns]
# 0    CIN1-
# Name: 1280, dtype: object
# c:\Users\taral\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but PCA was fitted without feature names
#   warnings.warn(

# %%
clf.predict(test_1_features)
# Out:
# array(['CIN1-'], dtype=object)

# %%
val_scaled = min_max_scaler.transform(val_df[feature_indices])

# %%
val_selected = pca.transform(
    val_scaled)

# %%
predicted = clf.predict(val_selected)

# %%
print(classification_report(val_df[label_index], predicted))
# Out:
#               precision    recall  f1-score   support
#
#        CIN1-       0.85      0.88      0.87        95
#        CIN2+       0.88      0.84      0.86        95
#
#     accuracy                           0.86       190
#    macro avg       0.86      0.86      0.86       190
# weighted avg       0.86      0.86      0.86       190

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
# create knn classifier
knn = KNeighborsClassifier(n_neighbors = 10)
#fit the data
knn.fit(selected,train_df[label_index])
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.predict(test_1_features)
# Out:
# array(['CIN1-'], dtype=object)

# %%
predicted = knn.predict(val_selected)
print(classification_report(val_df[label_index], predicted))
# Out:
#               precision    recall  f1-score   support
#
#        CIN1-       0.84      0.88      0.86        95
#        CIN2+       0.88      0.83      0.85        95
#
#     accuracy                           0.86       190
#    macro avg       0.86      0.86      0.86       190
# weighted avg       0.86      0.86      0.86       190

# %% [markdown]
# ## Search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([
    ('Extract', PCA()),
    ('Classify', svm.SVC())
])
param_grid = {
   'Extract__n_components': [5, 10, 50, 100, 500, 1000, 760],
   'Classify__kernel': ['linear', 'poly', 'rbf', 'sigmoid']}
search = GridSearchCV(pipe, param_grid).fit(scaled, train_df[label_index])
# Out:
# c:\Users\taral\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 140.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\taral\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\taral\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
search.best_estimator_
# Out:
# Pipeline(steps=[('Extract', PCA(n_components=5)),
#                 ('Classify', SVC(kernel='linear'))])

# %%
predicted = search.predict(val_scaled)

# %%
print(classification_report(val_df[label_index], predicted))
# Out:
#               precision    recall  f1-score   support
#
#        CIN1-       0.84      0.87      0.86        95
#        CIN2+       0.87      0.83      0.85        95
#
#     accuracy                           0.85       190
#    macro avg       0.85      0.85      0.85       190
# weighted avg       0.85      0.85      0.85       190
